# %% [markdown]
# # Matplotlib 소개

# %% [markdown]
# ![img](./img/img10.png)

# %% [markdown]
# Matplotlib은 데이터 시각화와 2D 그래프 플롯에 사용되는 파이썬 라이브러리
#
# Matplotlib을 이용하면 아래 그림과 같이 다양한 유형의 그래프를 간편하게 그릴 수 있음

# %% [markdown]
# ![img](./img/img11.png)

# %% [markdown]
# # Matplotlib 기본 사용
# ## Pyplot 소개
# matplotlib.pyplot 모듈의 각각의 함수를 사용해서 간편하게 그래프를 만들고 변화를 줄 수 있음
#
# 그래프 영역을 만들고, 몇 개의 선을 표현하고, 레이블로 꾸미는 등의 일을 할 수 있음
# ## 기본 그래프 그리기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# ## 스타일 지정하기

# %% [markdown]
# x, y 값 인자에 대해 선의 색상과 형태를 지정하는 포맷 문자열 (Format string)을 세번째 인자에 입력할 수 있음
#
# 포맷 문자열 ‘ro’는 빨간색 (‘red’)의 원형 (‘o’) 마커를 의미
#
# b-‘는 파란색 (‘blue’)의 실선 (‘-‘)을 의미

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro--')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ## 여러 개의 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## 레이블이 있는 데이터 사용하기

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.show()

# %% [markdown]
# # 여러가지 그래프 세팅
# 축 레이블, 범례, 축 범위, 선 종류, 마커, 색상, 축 스케일, 그리드, 눈금, 타이틀, 수평/수직선
# ## 축 레이블 설정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
plt.ylabel('Y-Axis', fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
plt.show()

# %% [markdown]
# ## 범례 표시하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.legend(loc='best')          # ncol = 1
plt.legend(loc='best', ncol=2, fontsize=12)    # ncol = 2

plt.show()

# %% [markdown]
# ## 축 범위 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]
# Out:
# (0.0, 20.0)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ## 선 종류, 컬러, 마커 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([4, 5, 6], '-', color='b', marker="H")
plt.plot([3, 4, 5], '--', color = 'g', marker="d")
plt.plot([2, 3, 4], ':', color = 'r', marker="x")
plt.plot([1, 2, 3], '-.', color = 'c', marker=11)
plt.plot([0, 1, 2], color = 'm', marker='$Z$')
plt.show()

# %% [markdown]
# ![img](./img/img12.png)
# ![img](./img/img13.png)
# ![img](./img/img14.png)

# %% [markdown]
# ##  축스케일 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
# plt.yscale('linear')
plt.yscale('log')

plt.show()

# %% [markdown]
# ## 그리드, 눈금 표시

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# ## 타이틀 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title')

plt.show()

# %% [markdown]
# ## 수평/수직선 표시하기

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=2)
plt.hlines(-0.62, 1.0, 2.5, color='gray', linestyle='solid', linewidth=3)

plt.show()

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axvline(1.0, 0.2, 0.8, color='lightgray', linestyle='--', linewidth=2)
plt.vlines(1.8, -3.0, 2.0, color='gray', linestyle='solid', linewidth=3)

plt.show()
